# %% [markdown]
# # Twitter Analytics with Python

# %% [markdown]
# Author: Kang P. Lee <br>
# References:
# - Mining the Social Web, 2nd Edition by Matthew A. Russel (http://shop.oreilly.com/product/0636920030195.do)
# - Twitter (Python package, https://pypi.python.org/pypi/twitter)
# - Twitter Application Management (https://apps.twitter.com/)
# - Twitter Developer Documentation (https://developer.twitter.com/en/docs)
# - Pandas (Python package, http://pandas.pydata.org/)
# - TextBlob (Python package, https://textblob.readthedocs.io/en/dev/)
# - Gender-guesser (Python package, https://pypi.python.org/pypi/gender-guesser)
# - Natural Language Toolkit (NLTK) (Python package, http://www.nltk.org/)
# - Wordcloud (Python package, https://pypi.python.org/pypi/wordcloud)
# - Matplotlib (Python package, https://matplotlib.org/)
# - NetworkX (Python package, https://networkx.github.io/)

# %% [markdown]
# ## Prerequisite

# %% [markdown]
# Run the following commands on the command line before you run the Jupyter Notenook server.
# You may use Terminal app on Mac or Anaconda Prompt on Windows.
# 1. pip install gender_guesser ipywidgets matplotlib nltk networkx pandas textblob twitter wordcloud
# 2. jupyter nbextension enable --py widgetsnbextension

# %%
! python -m nltk.downloader stopwords
! python -m textblob.download_corpora
# Out:
# /opt/anaconda3/lib/python3.6/runpy.py:125: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/kangplee/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package brown to /home/kangplee/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package punkt to /home/kangplee/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/kangplee/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /home/kangplee/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package conll2000 to
# [nltk_data]     /home/kangplee/nltk_data...
# [nltk_data]   Package conll2000 is already up-to-date!
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     /home/kangplee/nltk_data...
# [nltk_data]   Package movie_reviews is already up-to-date!
# Finished.

# %% [markdown]
# ## Import modules

# %%
from collections import Counter
from IPython.display import Image

import twitter
import pandas as pd
from textblob import TextBlob
import gender_guesser.detector as gender
from nltk.corpus import stopwords 
from wordcloud import WordCloud
from matplotlib import pyplot as plt
import networkx as nx
from ipywidgets import widgets, interactive

# %matplotlib inline
pd.set_option('display.max_colwidth', 200)
pd.set_option('display.float_format', '{:,.2f}'.format)

# %% [markdown]
# ## Connect to the Twitter API

# %%
###################################################################################
# Fill in the four credentials with your own information.
###################################################################################

CONSUMER_KEY = ""
CONSUMER_SECRET = ""                                                 
ACCESS_TOKEN = ""
ACCESS_TOKEN_SECRET = ""

# %% [markdown]
# Here's how to get the four credentials from Twitter:
# 1. Go to https://apps.twitter.com/ and sign in with your Twitter account.
# 2. Click the "Create New App" button at the top right of the screen.
# 3. Fill out the "Application Details". You can fill that out with any information you want, which is never important.
# 4. Check the developer agreement at the bottom and click "Create your Twitter application".
# 5. Now you see the application name you've just created. Click that.
# 6. Click the "Keys and Access Tokens" tab.
# 7. Find the following four values: Consumer Key (API Key), Consumer Secret (API Secret), Access Token, and Access Token Secret.

# %%
###################################################################################
# Establish a connection to the Twitter API.
###################################################################################

auth = twitter.oauth.OAuth(ACCESS_TOKEN, ACCESS_TOKEN_SECRET, CONSUMER_KEY, CONSUMER_SECRET)
twitter_api = twitter.Twitter(auth=auth)

# %% [markdown]
# ## Search for tweets with a search query

# %%
###################################################################################
# Make the first search call to the Twitter API.
###################################################################################

q = "trump"
search_results = twitter_api.search.tweets(q=q, count=100, lang="en", result_type="mixed")

# %% [markdown]
# - q: a search query of 500 characters maximum, including operators
# - count: the number of tweets to return per page, up to a maximum of 100
# - lang : restricts tweets to the given language
# - result_type: specifies what type of search results you would prefer to receive (mixed | recent | popular)
#
# Note that the search index has a 7-day limit. In other words, you can't search for tweets older than one week.
#
# Refer to https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets.html for details.

# %%
###################################################################################
# Check what's in 'search_results' as keys.
###################################################################################

search_results.keys()
# Out:
# dict_keys(['statuses', 'search_metadata'])

# %%
###################################################################################
# Check what's in 'search_metadata'.
###################################################################################

search_results["search_metadata"]
# Out:
# {'completed_in': 0.071,
#  'count': 100,
#  'max_id': 1010074570651525121,
#  'max_id_str': '1010074570651525121',
#  'next_results': '?max_id=1009605359600668671&q=trump&lang=en&count=100&include_entities=1&result_type=mixed',
#  'query': 'trump',
#  'refresh_url': '?since_id=1010074570651525121&q=trump&lang=en&result_type=mixed&include_entities=1',
#  'since_id': 0,
#  'since_id_str': '0'}

# %%
###################################################################################
# Check the number of records in 'statuses'.
# A status refers to an individual tweet.
###################################################################################

len(search_results["statuses"])
# Out:
# 100

# %%
###################################################################################
# Check the first record in 'statuses'.
###################################################################################

search_results["statuses"][0]
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Thu Jun 21 11:47:21 +0000 2018',
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#     'expanded_url': 'https://twitter.com/i/web/status/1009764707346075649',
#     'indices': [100, 123],
#     'url': 'https://t.co/iRrT5dtbp8'}],
#   'user_mentions': []},
#  'favorite_count': 65997,
#  'favorited': False,
#  'geo': None,
#  'id': 1009764707346075649,
#  'id_str': '1009764707346075649',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'popular'},
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 47157,
#  'retweeted': False,
#  'source': '<a href="http://www.socialflow.com" rel="nofollow">SocialFlow</a>',
#  'text': "TIME’s new cover: A reckoning after Trump's border separation policy: What kind of country are we?… https://t.co/iRrT5dtbp8",
#  'truncated': True,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Thu Apr 03 13:54:30 +0000 2008',
#   'default_profile': False,
#   'default_profile_image': False,
#   'description': 'Breaking news and current events from around the globe. Hosted by TIME staff.',
#   'entities': {'description': {'urls': []},
#    'url': {'urls': [{'display_url': 'time.com',
#       'expanded_url': 'http://www.time.com',
#       'indices': [0, 22],
#       'url': 'http://t.co/4aYbUuAeSh'}]}},
#   'favourites_count': 570,
#   'follow_request_sent': False,
#   'followers_count': 15654569,
#   'following': False,
#   'friends_count': 845,
#   'geo_enabled': True,
#   'has_extended_profile': False,
#   'id': 14293310,
#   'id_str': '14293310',
#   'is_translation_enabled': True,
#   'is_translator': False,
#   'lang': 'en',
#   'listed_count': 101258,
#   'location': '',
#   'name': 'TIME',
#   'notifications': False,
#   'profile_background_color': 'CC0000',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': True,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/14293310/1403546591',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/1700796190/Picture_24_normal.png',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1700796190/Picture_24_normal.png',
#   'profile_link_color': 'DE3333',
#   'profile_sidebar_border_color': '000000',
#   'profile_sidebar_fill_color': 'D9D9D9',
#   'profile_text_color': '000000',
#   'profile_use_background_image': True,
#   'protected': False,
#   'screen_name': 'TIME',
#   'statuses_count': 287905,
#   'time_zone': None,
#   'translator_type': 'regular',
#   'url': 'http://t.co/4aYbUuAeSh',
#   'utc_offset': None,
#   'verified': True}}

# %% [markdown]
# Refer to https://developer.twitter.com/en/docs/tweets/data-dictionary/overview/tweet-object for details.

# %%
###################################################################################
# Check the last record in 'statuses'.
###################################################################################

search_results["statuses"][-1]
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Fri Jun 22 08:18:29 +0000 2018',
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'urls': [],
#   'user_mentions': [{'id': 999595991689871360,
#     'id_str': '999595991689871360',
#     'indices': [3, 16],
#     'name': 'Candydandy...',
#     'screen_name': 'Candydandy19'},
#    {'id': 394724132,
#     'id_str': '394724132',
#     'indices': [18, 30],
#     'name': 'Topher Spiro',
#     'screen_name': 'TopherSpiro'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1010074531963105280,
#  'id_str': '1010074531963105280',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#  'place': None,
#  'retweet_count': 61,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Fri Jun 22 01:10:03 +0000 2018',
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#      'expanded_url': 'https://twitter.com/i/web/status/1009966714069479424',
#      'indices': [117, 140],
#      'url': 'https://t.co/4tT78rlvqj'}],
#    'user_mentions': [{'id': 394724132,
#      'id_str': '394724132',
#      'indices': [0, 12],
#      'name': 'Topher Spiro',
#      'screen_name': 'TopherSpiro'}]},
#   'favorite_count': 84,
#   'favorited': False,
#   'geo': None,
#   'id': 1009966714069479424,
#   'id_str': '1009966714069479424',
#   'in_reply_to_screen_name': 'TopherSpiro',
#   'in_reply_to_status_id': 1009946828408750080,
#   'in_reply_to_status_id_str': '1009946828408750080',
#   'in_reply_to_user_id': 394724132,
#   'in_reply_to_user_id_str': '394724132',
#   'is_quote_status': False,
#   'lang': 'en',
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 61,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': '@TopherSpiro Listen up America .. if your dependent on Medicare and Medicaid and your social security .. The GOP pa… https://t.co/4tT78rlvqj',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu May 24 10:20:30 +0000 2018',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': 'Sometimes happy and sometimes sad... sometimes a genius and sometimes clueless... I love to laugh at ridiculousness situations!   I’m a wife and mother.',
#    'entities': {'description': {'urls': []}},
#    'favourites_count': 570,
#    'follow_request_sent': False,
#    'followers_count': 38,
#    'following': False,
#    'friends_count': 97,
#    'geo_enabled': False,
#    'has_extended_profile': True,
#    'id': 999595991689871360,
#    'id_str': '999595991689871360',
#    'is_translation_enabled': False,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 1,
#    'location': 'California, USA',
#    'name': 'Candydandy...',
#    'notifications': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/999595991689871360/1527157558',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/999597222130958336/MMmGu3YE_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/999597222130958336/MMmGu3YE_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'Candydandy19',
#    'statuses_count': 657,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': None,
#    'utc_offset': None,
#    'verified': False}},
#  'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#  'text': 'RT @Candydandy19: @TopherSpiro Listen up America .. if your dependent on Medicare and Medicaid and your social security .. The GOP party an…',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Mon Jan 16 05:46:32 +0000 2017',
#   'default_profile': True,
#   'default_profile_image': False,
#   'description': 'Holy Chao & 93. No quarter for Nazis. ANTIFA. #theresistance #unhackthevote\n\nfaster harder denser more\nLog on Sign up Tune In Turn Up\n\nHettivong@counter.social',
#   'entities': {'description': {'urls': []}},
#   'favourites_count': 81418,
#   'follow_request_sent': False,
#   'followers_count': 2801,
#   'following': False,
#   'friends_count': 4999,
#   'geo_enabled': False,
#   'has_extended_profile': True,
#   'id': 820869825643712512,
#   'id_str': '820869825643712512',
#   'is_translation_enabled': False,
#   'is_translator': False,
#   'lang': 'en',
#   'listed_count': 25,
#   'location': 'Marburg DE & in your base.',
#   'name': 'Hetti Von Grell',
#   'notifications': False,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': None,
#   'profile_background_image_url_https': None,
#   'profile_background_tile': False,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/820869825643712512/1512421464',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/874836260451491841/p2UBFo7n_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874836260451491841/p2UBFo7n_normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'protected': False,
#   'screen_name': 'HettiVonG',
#   'statuses_count': 96935,
#   'time_zone': None,
#   'translator_type': 'none',
#   'url': None,
#   'utc_offset': None,
#   'verified': False}}

# %%
###################################################################################
# Check the first 30 tweet texts in 'statuses'.
###################################################################################

for status in search_results["statuses"][:30]:
    print(status["text"])
# Out:
# TIME’s new cover: A reckoning after Trump's border separation policy: What kind of country are we?… https://t.co/iRrT5dtbp8
# Here’s another zero tolerance program for the Trump Administration: EVERY child, EVERY baby has to be reunited with… https://t.co/e19PXYe4MH
# First, Trump created a crisis by repealing DACA, and threatened to deport DREAMErs if he didn’t get his wall.
#
# Next… https://t.co/45qfxDDvWe
# @parscale @KimKardashian Perhaps Kardashian would like to see USA transformed into a brutal dictatorship where peop… https://t.co/a0KNlaj2mq
# RT @EdKrassen: President Trump, who says he won't show up in court for a Robert Mueller subpoena, claims that we must detain immigrants ind…
# RT @EricHolder: Here’s another zero tolerance program for the Trump Administration: EVERY child, EVERY baby has to be reunited with his or…
# RT @Education4Libs: First Lady Melania Trump took the time to visit a child detention center today in Texas.
#
# Strange.
#
# I don’t recall Mich…
# RT @1Romans58: This POS is getting on my last nerve.  That fake smug smile needs to be removed.
#
# After Helping Plot &amp; Fund Trump Dossier,…
# RT @TomArnold: If you are triggered by the abuse of children the full facts of how The Trump Administration has been housing &amp; abusing chil…
# North Korea 'total denuclearisation' started; officials see no new moves - Trump - Reuters: Reuters North Korea 'to… https://t.co/F8zxPSgZzX
# RT @pollsofpolitics: What percentage number do you give @realDonaldTrump when it comes to his handling of the Economy???
#
# Vote and retweet…
# BREAKING: Horowitz Reveals Two More Anti-Trump Lawyers May Have Been Removed From Mueller Witch Hunt (VIDEO)… https://t.co/dkcmo03PcT
# RT @DGPurser: #MSM going after Trump.
# On your mark, get set, GO! https://t.co/MV7PfTSrZJ
# RT @JamesHouser56: @ScottPresler Notice anytime , which is almost daily that when President Trump does something Great for America , The Le…
# RT @traciemac_Bmore: Don’t let this IMPORTANT story slip by you while we debate Melania’s jacket: Cambridge Analytica had the Clinton email…
# RT @CBSNews: "Democrats love open borders... 'Let the whole world. MS-13, gang members from all over the place, come on in, we have open bo…
# RT @nick_clegg: My Brexit predictions from exactly two years ago. Too many are coming true for comfort, though I missed fruit rotting in th…
# @LynnDe6 @realDonaldTrump Dems put this laws into effect while Trump was still. Tv show host
# Both dems and reps are… https://t.co/LjwYxlJWPT
# @AK01541871 Top psychiatrist says President Trump is a genius #TCOT #CCOT
# https://t.co/rivKRfjDoM …
# Kim Kardashian West said she wants President Trump 'to win' and people are not happy https://t.co/tkCTMmlVzg
# RT @tonyschwartz: You have to understand that Trump literally feels nothing at all about those small children separated from their parents,…
# RT @CREWcrew: Coast Guard protection for Trump’s trips to Mar-a-Lago has cost taxpayers almost $20 million. That’s more than the Mueller in…
# RT @JohnWDean: Give Trump credit: He’s the PT Barnum of POTUS politics. Barnum famously said: “There's a sucker born every minute” and “I d…
# RT @AaeMae: I will never forgive y’all for making Trump President. NEVER.
# @FoxNews @ToroCoffeeCo @MariaBartiromo Can you name just one economic policy the Trump administration has put in to… https://t.co/aGmWM8QBoX
# RT @SafetyPinDaily: The bizarre blimp Trump won't like || By; David Aidone https://t.co/iuTn5Y5zF8
# Some White House officials are trying to restart talks with China to avoid a trade war, sources say… https://t.co/Ig22msbH4E
# RT @ShaunKing: This is where we are right now.
#
# Corey Lewandowski, Trump's campaign manager. literally says "Womp Womp" when it is mention…
# RT @boucherhayes: In fairness to Melania Trump she was planning on wearing a different coat but all the Dalmatian puppies escaped. https://…
# RT @MichaelRosenYes: The language says it all 'cleansing' here. Trump said 'infested'. Cameron talked of 'swarms'. The mass media recycle i…

# %% [markdown]
# ## Search for more tweets from Twitter

# %%
N = 10                     # Number of additional calls to the search API.

#########################################################################
# 'Results' will be used for accumulating all incoming data from Twitter.
# Start by storing the previous data in 'results'.
#########################################################################

results = []
results += search_results["statuses"]

#########################################################################
# Make N more iterative search calls with the same query.
#########################################################################

for _ in range(N):
    try:
        next_results = search_results["search_metadata"]["next_results"]
    except KeyError:
        break
    
    kwargs = dict([kv.split('=') for kv in next_results[1:].split("&")])
    search_results = twitter_api.search.tweets(**kwargs)
    
    print("%d tweets retrieved." %len(search_results["statuses"]))
    
    ##########################################################
    # Add the current search results to the overall results.
    ##########################################################
    
    results += search_results["statuses"]
# Out:
# 100 tweets retrieved.
# 100 tweets retrieved.
# 100 tweets retrieved.
# 100 tweets retrieved.
# 100 tweets retrieved.
# 100 tweets retrieved.
# 100 tweets retrieved.
# 100 tweets retrieved.
# 100 tweets retrieved.
# 100 tweets retrieved.

# %% [markdown]
# Due to Twitter's API rate policy, OAuth users can only make 180 search queries per 15-minute window.
#
# Refer to https://dev.twitter.com/rest/public/rate-limits for details.

# %%
#########################################################################
# Check the number of records in 'results'.
#########################################################################

len(results)
# Out:
# 1100

# %% [markdown]
# ## Save the data as a CSV file

# %% [markdown]
# It's alwasy a good idea to save the collected data, which is temporarily in the memory, as a file for secured and easier access to the data.

# %%
###################################################################################
# Simple function to remove special characters in text.
###################################################################################

def cleanse_text(text):
    text = text.replace("\n", "")
    text = text.replace("\r", "")
    text = text.replace("\t", "")
    text = text.replace("\"", "")
    
    return text

# %%
###################################################################################
# Write the data to a CSV file.
###################################################################################

with open(file="search_data.csv", mode="w", encoding="utf8") as fw:
    
    ###########################################################################################
    # Write the column names on the first row.
    # A tab (\t) acts as a seperator between columns and a new line (\n) as the end of a line. 
    ###########################################################################################
    
    fw.write("id\t" +
             "created_at\t" +
             "text\t" +
             "is_retweet\t" +
             "retweet_created_at\t" +
             "retweet_count\t" +
             "user_id\t" +
             "user_name\t" +
             "user_screen_name\t" + 
             "user_created_at\t" +
             "user_followers_count\t" +
             "user_statuses_count\t" +
             "user_location\t" +
             "user_desc\n")

    ###########################################################################################
    # Write the actual data starting from the second row by iterating over the 'results'.
    # A tab (\t) acts as a seperator between columns and a new line (\n) as the end of a line. 
    # Mare sure the order of column names matches the order in which the column values are written.
    ###########################################################################################
    
    for status in results:
        fw.write(status["id_str"] + "\t")
        fw.write(status["created_at"] + "\t")
        fw.write(cleanse_text(status["text"]) + "\t")
        
        if "retweeted_status" in status:
            fw.write("1\t")
            fw.write(status["retweeted_status"]["created_at"] + "\t")
        else:
            fw.write("0\t")
            fw.write("\t")
        
        fw.write(str(status["retweet_count"]) + "\t")
        fw.write(status["user"]["id_str"] + "\t")
        fw.write(status["user"]["name"] + "\t")
        fw.write(status["user"]["screen_name"] + "\t")
        fw.write(status["user"]["created_at"] + "\t")
        fw.write(str(status["user"]["followers_count"]) + "\t")
        fw.write(str(status["user"]["statuses_count"]) + "\t")
        fw.write(cleanse_text(status["user"]["location"]) + "\t")
        fw.write(cleanse_text(status["user"]["description"]) + "\t")
        fw.write("\n")

# %% [markdown]
# ## Load the CSV file as a Pandas dataframe

# %% [markdown]
# It's also a very good idea to start a social media analysis task by loading the dataset into a Pandas dataframe as it provides a wide range of data manipulation functionalities.

# %%
df = pd.read_csv("search_data.csv", sep="\t", header=0, parse_dates=[1, 11], index_col=False)

# %% [markdown]
# If you don't see any errors, that means your dataset has been successfully loaded into a Pandas dataframe. If you see any errors, that means there have been some problems in parsing and loading the dataset.

# %% [markdown]
# ## Get familiar with the dataset

# %%
df.shape
# Out:
# (1100, 14)

# %% [markdown]
# The dataframe <i>df</i> is a 1100 x 14 table, which means there are 1100 rows, or records, and 14 columns, or fields.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 14 columns):
# id                      1100 non-null int64
# created_at              1100 non-null datetime64[ns]
# text                    1100 non-null object
# is_retweet              1100 non-null int64
# retweet_created_at      897 non-null object
# retweet_count           1100 non-null int64
# user_id                 1100 non-null int64
# user_name               1100 non-null object
# user_screen_name        1100 non-null object
# user_created_at         1100 non-null object
# user_followers_count    1100 non-null int64
# user_statuses_count     1100 non-null object
# user_location           762 non-null object
# user_desc               888 non-null object
# dtypes: datetime64[ns](1), int64(5), object(8)
# memory usage: 120.4+ KB

# %%
df.columns
# Out:
# Index(['id', 'created_at', 'text', 'is_retweet', 'retweet_created_at',
#        'retweet_count', 'user_id', 'user_name', 'user_screen_name',
#        'user_created_at', 'user_followers_count', 'user_statuses_count',
#        'user_location', 'user_desc'],
#       dtype='object')

# %%
df.head()
# Out:
#                     id          created_at  \
# 0  1009764707346075649 2018-06-21 11:47:21
# 1  1009897068503207936 2018-06-21 20:33:18
# 2  1009605359600668672 2018-06-21 01:14:09
# 3  1010074570651525121 2018-06-22 08:18:38
# 4  1010074570299232258 2018-06-22 08:18:38
#
#                                                                                                                                            text  \
# 0                   TIME’s new cover: A reckoning after Trump's border separation policy: What kind of country are we?… https://t.co/iRrT5dtbp8
# 1  Here’s another zero tolerance program for the Trump Administration: EVERY child, EVERY baby has to be reunited with… https://t.co/e19PXYe4MH
# 2    First, Trump created a crisis by repealing DACA, and threatened to deport DREAMErs if he didn’t get his wall.Next… https://t.co/45qfxDDvWe
# 3  @parscale @KimKardashian Perhaps Kardashian would like to see USA transformed into a brutal dictatorship where peop… https://t.co/a0KNlaj2mq
# 4  RT @EdKrassen: President Trump, who says he won't show up in court for a Robert Mueller subpoena, claims that we must detain immigrants ind…
#
#    is_retweet              retweet_created_at  retweet_count  \
# 0           0                             NaN          47157
# 1           0                             NaN          17914
# 2           0                             NaN          32136
# 3           0                             NaN              0
# 4           1  Fri Jun 22 00:11:00 +0000 2018           3725
#
#               user_id     user_name user_screen_name  \
# 0            14293310          TIME             TIME
# 1          3333055535   Eric Holder       EricHolder
# 2            29501253   Adam Schiff    RepAdamSchiff
# 3  966683797382205440         Jarin    Jarin50926789
# 4            86792097  SharonBohn 🌊  BookishBeachBum
#
#                   user_created_at  user_followers_count user_statuses_count  \
# 0  Thu Apr 03 13:54:30 +0000 2008              15654569              287905
# 1  Thu Jun 18 17:40:27 +0000 2015                380582                 396
# 2  Tue Apr 07 17:54:35 +0000 2009                970597                4601
# 3  Thu Feb 22 14:39:12 +0000 2018                     5                2424
# 4  Sun Nov 01 20:11:03 +0000 2009                  1698               22415
#
#                    user_location  \
# 0                            NaN
# 1                            NaN
# 2                    Burbank, CA
# 3                            NaN
# 4  Beyond your peripheral vision
#
#                                                                                                                                                     user_desc
# 0                                                                               Breaking news and current events from around the globe. Hosted by TIME staff.
# 1                                                                                                                                                       AG 82
# 2                                               Representing California's 28th Congressional District and Ranking Member of the House Intelligence Committee.
# 3                                                                                                                                                         NaN
# 4  Wanderer, Christian, wino, future ex-pat living blue in a red state imagining Sisyphus as happy. Oxford comma or GTFO#amwriting #Resistance #ePluribusUnum

# %%
df.tail()
# Out:
#                        id          created_at  \
# 1095  1009605285558800384 2018-06-21 01:13:52
# 1096  1009605285550252032 2018-06-21 01:13:52
# 1097  1009605285546250241 2018-06-21 01:13:52
# 1098  1009605285453836288 2018-06-21 01:13:52
# 1099  1009605285407744000 2018-06-21 01:13:52
#
#                                                                                                                                               text  \
# 1095                       RT @WiredSources: Massive crowd awaiting President Trump remarks at a rally in Duluth, Minnesotahttps://t.co/a9wbldnMzm
# 1096                                                  RT @Salon: It’s long past time to compare Donald Trump and the Nazis https://t.co/A6csHfSQ1K
# 1097     RT @ECMcLaughlin: In case you thought we'd won today, I give you the actual language.The Secretary of Homeland Security (Secretary), sha…
# 1098  RT @greggutfeld: Trump made a point as an aside: he's an elitist in wealth and property, yet embraced by working class. that unravels the D…
# 1099  RT @MrFilmkritik: Trump just signed an Executive Order he didn't need to sign to end a policy that he created and the White House said didn…
#
#       is_retweet              retweet_created_at  retweet_count  \
# 1095           1  Wed Jun 20 23:20:31 +0000 2018           3397
# 1096           1  Wed Jun 20 23:13:23 +0000 2018            104
# 1097           1  Thu Jun 21 00:57:43 +0000 2018             69
# 1098           1  Thu Jun 21 00:38:14 +0000 2018           4912
# 1099           1  Wed Jun 20 19:33:12 +0000 2018          24852
#
#                  user_id                  user_name user_screen_name  \
# 1095           326825780                    chuck21        Chuck3960
# 1096           465193761                     Pete G       PGeorgatos
# 1097           476388891  “Mentally Unfit” Resister            mh451
# 1098  717746159091982337                       Mary   MaryEllen85635
# 1099            42084835         Jacquelyn Reynolds      buoyantbabe
#
#                      user_created_at  user_followers_count  \
# 1095  Thu Jun 30 15:10:29 +0000 2011                   656
# 1096  Mon Jan 16 02:31:46 +0000 2012                    95
# 1097  Sat Jan 28 02:44:45 +0000 2012                   467
# 1098  Wed Apr 06 16:09:54 +0000 2016                  5954
# 1099  Sat May 23 19:42:32 +0000 2009                    65
#
#      user_statuses_count    user_location  \
# 1095               36965              NaN
# 1096               18285              NaN
# 1097                8074            Earth
# 1098               23604     Arizona, USA
# 1099                3535  Alberta, Canada
#
#                                                                                                                                                        user_desc
# 1095  Any people that would give up liberty for a little temporary safety deserves neither liberty nor safety. Benjamin Franklin, Against any form of Liberalism
# 1096                                                                                                                                                         NaN
# 1097                #FBR. Concerned citizen. #Resist #Trump's #taxscam bankrupting U.S. What about Hillary (a retort to #MAGA). R/Ts ≠ endorsement(s). No Lists.
# 1098                                               #MAGA 🇺🇸Donald J Trump 👉#BestPresidentEver Thank God 👼Hillary isn't anyone's presidenthttps://t.co/sSPqK48kCk
# 1099                                                                                                                                                         NaN

# %%
df.created_at
# Out:
# 0      2018-06-21 11:47:21
# 1      2018-06-21 20:33:18
# 2      2018-06-21 01:14:09
# 3      2018-06-22 08:18:38
# 4      2018-06-22 08:18:38
# 5      2018-06-22 08:18:38
# 6      2018-06-22 08:18:38
# 7      2018-06-22 08:18:38
# 8      2018-06-22 08:18:38
# 9      2018-06-22 08:18:38
# 10     2018-06-22 08:18:38
# 11     2018-06-22 08:18:38
# 12     2018-06-22 08:18:38
# 13     2018-06-22 08:18:38
# 14     2018-06-22 08:18:37
# 15     2018-06-22 08:18:37
# 16     2018-06-22 08:18:37
# 17     2018-06-22 08:18:37
# 18     2018-06-22 08:18:37
# 19     2018-06-22 08:18:37
# 20     2018-06-22 08:18:37
# 21     2018-06-22 08:18:37
# 22     2018-06-22 08:18:37
# 23     2018-06-22 08:18:37
# 24     2018-06-22 08:18:37
# 25     2018-06-22 08:18:37
# 26     2018-06-22 08:18:36
# 27     2018-06-22 08:18:36
# 28     2018-06-22 08:18:36
# 29     2018-06-22 08:18:36
#                ...
# 1070   2018-06-21 01:13:52
# 1071   2018-06-21 01:13:52
# 1072   2018-06-21 01:13:52
# 1073   2018-06-21 01:13:52
# 1074   2018-06-21 01:13:52
# 1075   2018-06-21 01:13:52
# 1076   2018-06-21 01:13:52
# 1077   2018-06-21 01:13:52
# 1078   2018-06-21 01:13:52
# 1079   2018-06-21 01:13:52
# 1080   2018-06-21 01:13:52
# 1081   2018-06-21 01:13:52
# 1082   2018-06-21 01:13:52
# 1083   2018-06-21 01:13:52
# 1084   2018-06-21 01:13:52
# 1085   2018-06-21 01:13:52
# 1086   2018-06-21 01:13:52
# 1087   2018-06-21 01:13:52
# 1088   2018-06-21 01:13:52
# 1089   2018-06-21 01:13:52
# 1090   2018-06-21 01:13:52
# 1091   2018-06-21 01:13:52
# 1092   2018-06-21 01:13:52
# 1093   2018-06-21 01:13:52
# 1094   2018-06-21 01:13:52
# 1095   2018-06-21 01:13:52
# 1096   2018-06-21 01:13:52
# 1097   2018-06-21 01:13:52
# 1098   2018-06-21 01:13:52
# 1099   2018-06-21 01:13:52
# Name: created_at, Length: 1100, dtype: datetime64[ns]

# %% [markdown]
# ## Enrich the columns with tweet sentiment

# %% [markdown]
# Let's add two new columns named <i>polarity</i> and <i>subjectivity</i> that indicate how positive/negative and subjective the tweet text is.

# %%
text = "It's just awesome!"
tb = TextBlob(text)

# %%
tb.sentiment     # polarity between -1 (negative) and 1 (positive) 
                 # subjectivity between 0 (objective) and 1 (subjective)
# Out:
# Sentiment(polarity=1.0, subjectivity=1.0)

# %%
tb.sentiment.polarity
# Out:
# 1.0

# %%
###################################################################################
# Create a new column 'polairty' in 'df' and fill the column with the polarity of 
# the tweet text by iterating over all the texts under 'df.text' one by one.
###################################################################################

df["polarity"] = df.text.apply(lambda x: TextBlob(str(x)).sentiment.polarity)

# %%
df["subjectivity"] = df.text.apply(lambda x: TextBlob(str(x)).sentiment.subjectivity)

# %%
df.columns
# Out:
# Index(['id', 'created_at', 'text', 'is_retweet', 'retweet_created_at',
#        'retweet_count', 'user_id', 'user_name', 'user_screen_name',
#        'user_created_at', 'user_followers_count', 'user_statuses_count',
#        'user_location', 'user_desc', 'polarity', 'subjectivity'],
#       dtype='object')

# %%
df[["text", "polarity", "subjectivity"]].head(10)
# Out:
#                                                                                                                                                text  \
# 0                       TIME’s new cover: A reckoning after Trump's border separation policy: What kind of country are we?… https://t.co/iRrT5dtbp8
# 1      Here’s another zero tolerance program for the Trump Administration: EVERY child, EVERY baby has to be reunited with… https://t.co/e19PXYe4MH
# 2        First, Trump created a crisis by repealing DACA, and threatened to deport DREAMErs if he didn’t get his wall.Next… https://t.co/45qfxDDvWe
# 3      @parscale @KimKardashian Perhaps Kardashian would like to see USA transformed into a brutal dictatorship where peop… https://t.co/a0KNlaj2mq
# 4      RT @EdKrassen: President Trump, who says he won't show up in court for a Robert Mueller subpoena, claims that we must detain immigrants ind…
# 5       RT @EricHolder: Here’s another zero tolerance program for the Trump Administration: EVERY child, EVERY baby has to be reunited with his or…
# 6          RT @Education4Libs: First Lady Melania Trump took the time to visit a child detention center today in Texas.Strange.I don’t recall Mich…
# 7     RT @1Romans58: This POS is getting on my last nerve.  That fake smug smile needs to be removed. After Helping Plot &amp; Fund Trump Dossier,…
# 8  RT @TomArnold: If you are triggered by the abuse of children the full facts of how The Trump Administration has been housing &amp; abusing chil…
# 9      North Korea 'total denuclearisation' started; officials see no new moves - Trump - Reuters: Reuters North Korea 'to… https://t.co/F8zxPSgZzX
#
#    polarity  subjectivity
# 0      0.37          0.68
# 1      0.00          0.00
# 2      0.25          0.33
# 3     -0.88          1.00
# 4      0.00          0.00
# 5      0.00          0.00
# 6      0.07          0.22
# 7     -0.07          0.39
# 8      0.35          0.55
# 9     -0.03          0.60

# %%
df[(df.polarity > 0.7) | (df.polarity < -0.7)][["text", "polarity"]].head(10)
# Out:
#                                                                                                                                                      text  \
# 3            @parscale @KimKardashian Perhaps Kardashian would like to see USA transformed into a brutal dictatorship where peop… https://t.co/a0KNlaj2mq
# 83           RT @NikitaKitty: Trump backs plan to end family separations but shirks responsibility https://t.co/1z4QQbEYRM This disgusting lump of inhum…
# 84                 RT @GermanyKent: Rosalynn Carter: “disgraceful and a shame to our country” Laura Bush: zero-tolerance policy is cruel and immoralHill…
# 106      RT @timothywookey: Madonna says #trump is disgusting &amp; needs to reunite migrant children with their parents immediately. Now he has caved i…
# 133          RT @MrFilmkritik: While you weren't paying attention, Trump rescinded an Obama policy that was meant to protect the Great Lakes and the oce…
# 148          @RobertBakerUSA @juanwilliams @TheJuanWilliams you are a demented, disgusting, Democrat who's defending peter fonda… https://t.co/V0WdN954SF
# 199  RT @RepMaxineWaters: Remember when I said Trump &amp; his allies are scumbags? Trump is an immoral, indecent, &amp; inhumane thug.  He loves Putin,…
# 200                                                                                                             Goldman = Cruel   https://t.co/3TUm6MTjGP
# 229  RT @RepMaxineWaters: Remember when I said Trump &amp; his allies are scumbags? Trump is an immoral, indecent, &amp; inhumane thug.  He loves Putin,…
# 238                                                      RT @Lrihendry: I still feel sick about Peter Fonda’s tweet about Baron Trump. It was horrible. 😢
#
#      polarity
# 3       -0.88
# 83      -1.00
# 84      -1.00
# 106     -1.00
# 133      0.80
# 148     -1.00
# 199     -0.90
# 200     -1.00
# 229     -0.90
# 238     -0.86

# %% [markdown]
# ## Enrich the columns with part-of-speech (PoS) tags

# %% [markdown]
# Let's add a new column named <i>tags</i> that contains the part-of-speech tags of the tweet text.

# %%
text = "It's just awesome!"
tb = TextBlob(text)

# %%
tb.tags
# Out:
# [('It', 'PRP'), ("'s", 'VBZ'), ('just', 'RB'), ('awesome', 'JJ')]

# %% [markdown]
# Refer to https://cs.nyu.edu/grishman/jet/guide/PennPOS.html for details on the part-of-speech tags.

# %%
###################################################################################
# Create a new column 'tags' in 'df' and fill the column with the part-of-the-speech
# tags of the tweet text by iterating over all the texts under 'df.text' one by one.
###################################################################################

df["tags"] = df.text.apply(lambda x: TextBlob(x).tags)

# %%
df.columns
# Out:
# Index(['id', 'created_at', 'text', 'is_retweet', 'retweet_created_at',
#        'retweet_count', 'user_id', 'user_name', 'user_screen_name',
#        'user_created_at', 'user_followers_count', 'user_statuses_count',
#        'user_location', 'user_desc', 'polarity', 'subjectivity', 'tags'],
#       dtype='object')

# %%
df[["text", "tags"]].head(10)
# Out:
#                                                                                                                                                text  \
# 0                       TIME’s new cover: A reckoning after Trump's border separation policy: What kind of country are we?… https://t.co/iRrT5dtbp8
# 1      Here’s another zero tolerance program for the Trump Administration: EVERY child, EVERY baby has to be reunited with… https://t.co/e19PXYe4MH
# 2        First, Trump created a crisis by repealing DACA, and threatened to deport DREAMErs if he didn’t get his wall.Next… https://t.co/45qfxDDvWe
# 3      @parscale @KimKardashian Perhaps Kardashian would like to see USA transformed into a brutal dictatorship where peop… https://t.co/a0KNlaj2mq
# 4      RT @EdKrassen: President Trump, who says he won't show up in court for a Robert Mueller subpoena, claims that we must detain immigrants ind…
# 5       RT @EricHolder: Here’s another zero tolerance program for the Trump Administration: EVERY child, EVERY baby has to be reunited with his or…
# 6          RT @Education4Libs: First Lady Melania Trump took the time to visit a child detention center today in Texas.Strange.I don’t recall Mich…
# 7     RT @1Romans58: This POS is getting on my last nerve.  That fake smug smile needs to be removed. After Helping Plot &amp; Fund Trump Dossier,…
# 8  RT @TomArnold: If you are triggered by the abuse of children the full facts of how The Trump Administration has been housing &amp; abusing chil…
# 9      North Korea 'total denuclearisation' started; officials see no new moves - Trump - Reuters: Reuters North Korea 'to… https://t.co/F8zxPSgZzX
#
#                                                                                                                                                                                                       tags
# 0  [(TIME, NNP), (’, NNP), (s, VBD), (new, JJ), (cover, NN), (A, DT), (reckoning, NN), (after, IN), (Trump, NNP), ('s, POS), (border, NN), (separation, NN), (policy, NN), (What, WP), (kind, NN), (of,...
# 1  [(Here, RB), (’, NNP), (s, VBZ), (another, DT), (zero, NN), (tolerance, NN), (program, NN), (for, IN), (the, DT), (Trump, NNP), (Administration, NNP), (EVERY, NNP), (child, NN), (EVERY, NNP), (bab...
# 2  [(First, RB), (Trump, NNP), (created, VBD), (a, DT), (crisis, NN), (by, IN), (repealing, VBG), (DACA, NNP), (and, CC), (threatened, VBD), (to, TO), (deport, VB), (DREAMErs, NNP), (if, IN), (he, PR...
# 3  [(@, JJ), (parscale, NN), (@, NN), (KimKardashian, NNP), (Perhaps, RB), (Kardashian, NNP), (would, MD), (like, VB), (to, TO), (see, VB), (USA, NNP), (transformed, VBD), (into, IN), (a, DT), (bruta...
# 4  [(RT, NNP), (@, NNP), (EdKrassen, NNP), (President, NNP), (Trump, NNP), (who, WP), (says, VBZ), (he, PRP), (wo, MD), (n't, RB), (show, VB), (up, RP), (in, IN), (court, NN), (for, IN), (a, DT), (Ro...
# 5  [(RT, NNP), (@, NNP), (EricHolder, NNP), (Here, RB), (’, VBZ), (s, NN), (another, DT), (zero, CD), (tolerance, NN), (program, NN), (for, IN), (the, DT), (Trump, NNP), (Administration, NNP), (EVERY...
# 6  [(RT, NNP), (@, NNP), (Education4Libs, NNP), (First, NNP), (Lady, NNP), (Melania, NNP), (Trump, NNP), (took, VBD), (the, DT), (time, NN), (to, TO), (visit, VB), (a, DT), (child, JJ), (detention, N...
# 7  [(RT, NNP), (@, VBD), (1Romans58, CD), (This, DT), (POS, NNP), (is, VBZ), (getting, VBG), (on, IN), (my, PRP$), (last, JJ), (nerve, NN), (That, DT), (fake, VBP), (smug, JJ), (smile, NN), (needs, N...
# 8  [(RT, NNP), (@, NNP), (TomArnold, NNP), (If, IN), (you, PRP), (are, VBP), (triggered, VBN), (by, IN), (the, DT), (abuse, NN), (of, IN), (children, NNS), (the, DT), (full, JJ), (facts, NNS), (of, I...
# 9  [(North, NNP), (Korea, NNP), ('total, POS), (denuclearisation, NN), (started, VBN), (officials, NNS), (see, VBP), (no, DT), (new, JJ), (moves, NNS), (Trump, NNP), (Reuters, NNS), (Reuters, NNS), (...

# %% [markdown]
# ## Enrich the columns with user gender

# %% [markdown]
# Let's add a new column named <i>user_gender</i> that indicates the gender of the Twitter user.

# %%
d = gender.Detector(case_sensitive=False)

# %%
d.get_gender("Bob"), d.get_gender("Sally"), d.get_gender("Pauley"), d.get_gender("Jamie"), d.get_gender("Iowa")
# Out:
# ('male', 'female', 'andy', 'mostly_female', 'unknown')

# %% [markdown]
# The gender-guesser returns six types of gender:
# - female
# - male
# - mostly_female
# - mostly_male
# - unknown (name not found)
# - andy (androgynous)
#
# Refer to https://pypi.python.org/pypi/gender-guesser for details on gender-guesser.

# %%
def get_gender(name):
    first_name = name.split()[0]            # Get the first name.
    user_gender = d.get_gender(first_name)
    
    ######################################################################
    # For simplicity, treat most_female as female and most_male as male.
    ######################################################################
    
    if user_gender == "mostly_female":
        user_gender = "female"
    elif user_gender == "mostly_male":
        user_gender = "male"
    
    return user_gender

df["user_gender"] = df.user_name.apply(lambda x: get_gender(x))

# %%
df.columns
# Out:
# Index(['id', 'created_at', 'text', 'is_retweet', 'retweet_created_at',
#        'retweet_count', 'user_id', 'user_name', 'user_screen_name',
#        'user_created_at', 'user_followers_count', 'user_statuses_count',
#        'user_location', 'user_desc', 'polarity', 'subjectivity', 'tags',
#        'user_gender'],
#       dtype='object')

# %%
df[["user_name", "user_gender"]].head(10)
# Out:
#                    user_name user_gender
# 0                       TIME     unknown
# 1                Eric Holder        male
# 2                Adam Schiff        male
# 3                      Jarin     unknown
# 4               SharonBohn 🌊     unknown
# 5             Idella Sherrod      female
# 6               Bill Feltham        male
# 7           Deplorable Lessa     unknown
# 8  kaz #KeepFamiliesTogether     unknown
# 9               Yasmin Mitri      female

# %% [markdown]
# ## Statistical overview of the dataset

# %%
df.describe()
# Out:
#                                 id  is_retweet  retweet_count  \
# count                     1,100.00    1,100.00       1,100.00
# mean  1,009,647,110,571,188,224.00        0.82       3,944.12
# std         133,364,349,022,453.36        0.39       9,578.54
# min   1,009,605,285,407,744,000.00        0.00           0.00
# 25%   1,009,605,306,592,206,848.00        1.00          10.00
# 50%   1,009,605,325,834,612,736.00        1.00         398.00
# 75%   1,009,605,347,537,907,712.00        1.00       3,224.00
# max   1,010,074,570,651,525,120.00        1.00      69,093.00
#
#                            user_id  user_followers_count  polarity  \
# count                     1,100.00              1,100.00  1,100.00
# mean    259,617,013,782,013,056.00             19,248.72      0.00
# std     397,001,966,180,938,112.00            473,614.07      0.30
# min                   5,539,902.00                  0.00     -1.00
# 25%                 245,168,971.50                181.50     -0.05
# 50%               1,498,213,514.00                615.50      0.00
# 75%     770,490,059,391,857,664.00              2,021.25      0.10
# max   1,010,072,265,222,860,800.00         15,654,569.00      1.00
#
#        subjectivity
# count      1,100.00
# mean           0.35
# std            0.34
# min            0.00
# 25%            0.00
# 50%            0.30
# 75%            0.60
# max            1.00

# %% [markdown]
# ## Popular keywords

# %%
###################################################################################
# The 'counter' object will have all the word count information. 
###################################################################################

counter = Counter()

for tags in df.tags:
    
    ###################################################################
    # Use a set to remove duplicate words.
    # This enables us to count every term in a tweet as just 1 
    # even though they appear multiple times in the same tweet. 
    ###################################################################
    
    word_set = set()
    
    for item in tags:
        word = item[0].lower()
        word_set.add(word)
            
    counter.update(word_set)

# %%
###################################################################################
# Check the top-k popular words in 'counter'. 
###################################################################################

counter.most_common(30)
# Out:
# [('@', 1016),
#  ('rt', 898),
#  ('trump', 830),
#  ('the', 525),
#  ('to', 441),
#  ('a', 352),
#  ('and', 301),
#  ('is', 278),
#  ('https', 271),
#  ('of', 259),
#  ('in', 220),
#  ('’', 208),
#  ("'s", 193),
#  ('for', 188),
#  ('that', 159),
#  ('it', 151),
#  ('this', 142),
#  ('on', 139),
#  ('i', 137),
#  ('he', 133),
#  ('s', 130),
#  ('are', 121),
#  ('you', 120),
#  ('president', 107),
#  ('has', 106),
#  ('we', 105),
#  ('from', 104),
#  ('his', 101),
#  ('with', 98),
#  ('children', 97)]

# %%
###################################################################################
# Use a list of English stopwords provided by NLTK. 
###################################################################################

global_stopwords = stopwords.words("english")
global_stopwords[:30]
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself']

# %%
counter = Counter()

for tags in df.tags:
    word_set = set()
    
    for item in tags:
        word = item[0].lower()
        
        ###################################
        # Check if the word is a stopword.
        ###################################
        if word in global_stopwords:
            continue
        else:
            word_set.add(word)
            
    counter.update(word_set)
    
counter.most_common(30)
# Out:
# [('@', 1016),
#  ('rt', 898),
#  ('trump', 830),
#  ('https', 271),
#  ('’', 208),
#  ("'s", 193),
#  ('president', 107),
#  ('children', 97),
#  ("n't", 95),
#  ('order', 95),
#  ('executive', 87),
#  ('policy', 85),
#  ('families', 57),
#  ('rally', 55),
#  ('administration', 54),
#  ('family', 54),
#  ('…', 51),
#  ('“', 51),
#  ('one', 51),
#  ('people', 50),
#  ('parents', 50),
#  ('said', 48),
#  ('separated', 47),
#  ('says', 44),
#  ('going', 44),
#  ('donald', 44),
#  ('realdonaldtrump', 41),
#  ('duluth', 39),
#  ('&', 38),
#  ('”', 38)]

# %%
local_stopwords = ["@", "&", "‘", "’", "“", "”", "…", "'", "'s", "amp", "https", "donald", "n't", "president", "rt", "trump"]

counter = Counter()
for tags in df.tags:
    word_set = set()
    
    for item in tags:
        word = item[0].lower()
        
        ##########################################################
        # Check if the word is either a global or local stopword.
        ##########################################################
        
        if word in (global_stopwords + local_stopwords):
            continue
        else:
            word_set.add(word)
            
    counter.update(word_set)
    
counter.most_common(30)
# Out:
# [('children', 97),
#  ('order', 95),
#  ('executive', 87),
#  ('policy', 85),
#  ('families', 57),
#  ('rally', 55),
#  ('administration', 54),
#  ('family', 54),
#  ('one', 51),
#  ('people', 50),
#  ('parents', 50),
#  ('said', 48),
#  ('separated', 47),
#  ('says', 44),
#  ('going', 44),
#  ('realdonaldtrump', 41),
#  ('duluth', 39),
#  ('fonda', 38),
#  ('signed', 38),
#  ('end', 37),
#  ('breaking', 35),
#  ('peter', 35),
#  ('news', 34),
#  ('white', 33),
#  ('border', 32),
#  ('still', 31),
#  ('house', 31),
#  ('sign', 31),
#  ('need', 30),
#  ('time', 29)]

# %% [markdown]
# ## Visualize a word cloud

# %%
wc = WordCloud(background_color="white", max_words=100, width=800, height=500)
wc.generate_from_frequencies(counter)
wc.to_file("wordcloud.png")

Image(filename="wordcloud.png")

# %% [markdown]
# ## Popular Adjectives

# %%
counter = Counter()
for tags in df.tags:
    word_set = set()
    
    for item in tags:
        word = item[0].lower()
        tag = item[1]
        
        if word in (global_stopwords + local_stopwords):
            continue
        
        ##########################################################
        # Check if the tag is the adjective.
        ##########################################################
        
        if tag in ["JJ", "JJR", "JJS"]:
            word_set.add(word)
            
    counter.update(word_set)
    
counter.most_common(30)
# Out:
# [('many', 17),
#  ('little', 16),
#  ('successful', 16),
#  ('immigrant', 14),
#  ('american', 14),
#  ('alternative', 13),
#  ('last', 12),
#  ('twelve-year-old', 12),
#  ('pro-active', 12),
#  ('vigorous', 12),
#  ('right', 11),
#  ('executive', 11),
#  ('wrong', 11),
#  ('unexpected', 11),
#  ('guilty', 11),
#  ('good', 10),
#  ('old', 10),
#  ('human', 10),
#  ('illegal', 10),
#  ('massive', 10),
#  ('na', 9),
#  ('anti-trump', 8),
#  ('moral', 8),
#  ('new', 7),
#  ('crazy', 7),
#  ('military', 7),
#  ('better', 7),
#  ('sick', 7),
#  ('bad', 7),
#  ('entire', 7)]

# %%
wc = WordCloud(background_color="white", max_words=100, width=800, height=500)
wc.generate_from_frequencies(counter)
wc.to_file("wordcloud_adj.png")

Image(filename="wordcloud_adj.png")

# %% [markdown]
# ## Popular retweets

# %%
df[["text", "retweet_count"]].head(10)
# Out:
#                                                                                                                                                text  \
# 0                       TIME’s new cover: A reckoning after Trump's border separation policy: What kind of country are we?… https://t.co/iRrT5dtbp8
# 1      Here’s another zero tolerance program for the Trump Administration: EVERY child, EVERY baby has to be reunited with… https://t.co/e19PXYe4MH
# 2        First, Trump created a crisis by repealing DACA, and threatened to deport DREAMErs if he didn’t get his wall.Next… https://t.co/45qfxDDvWe
# 3      @parscale @KimKardashian Perhaps Kardashian would like to see USA transformed into a brutal dictatorship where peop… https://t.co/a0KNlaj2mq
# 4      RT @EdKrassen: President Trump, who says he won't show up in court for a Robert Mueller subpoena, claims that we must detain immigrants ind…
# 5       RT @EricHolder: Here’s another zero tolerance program for the Trump Administration: EVERY child, EVERY baby has to be reunited with his or…
# 6          RT @Education4Libs: First Lady Melania Trump took the time to visit a child detention center today in Texas.Strange.I don’t recall Mich…
# 7     RT @1Romans58: This POS is getting on my last nerve.  That fake smug smile needs to be removed. After Helping Plot &amp; Fund Trump Dossier,…
# 8  RT @TomArnold: If you are triggered by the abuse of children the full facts of how The Trump Administration has been housing &amp; abusing chil…
# 9      North Korea 'total denuclearisation' started; officials see no new moves - Trump - Reuters: Reuters North Korea 'to… https://t.co/F8zxPSgZzX
#
#    retweet_count
# 0          47157
# 1          17914
# 2          32136
# 3              0
# 4           3725
# 5          17914
# 6           7379
# 7            847
# 8            379
# 9              0

# %%
df_sub = df[["text", "retweet_count"]]

###################################################################################
# Sort the 'df_sub' by 'retweet_count' in descending order. 
###################################################################################

df_sub.sort_values(by="retweet_count", ascending=False).head(30)
# Out:
#                                                                                                                                                 text  \
# 76      RT @SteveSchmidtSES: 29 years and nine months ago I registered to vote and became a member of The Republican Party which was founded in 185…
# 153     RT @SteveSchmidtSES: 29 years and nine months ago I registered to vote and became a member of The Republican Party which was founded in 185…
# 275     RT @SteveSchmidtSES: 29 years and nine months ago I registered to vote and became a member of The Republican Party which was founded in 185…
# 413     RT @SteveSchmidtSES: 29 years and nine months ago I registered to vote and became a member of The Republican Party which was founded in 185…
# 570     RT @SteveSchmidtSES: 29 years and nine months ago I registered to vote and became a member of The Republican Party which was founded in 185…
# 587     RT @SteveSchmidtSES: 29 years and nine months ago I registered to vote and became a member of The Republican Party which was founded in 185…
# 842     RT @SteveSchmidtSES: 29 years and nine months ago I registered to vote and became a member of The Republican Party which was founded in 185…
# 738          RT @jessehawken: 2016: Come on, you're talking like Trump's going to put people in concentration camps2018: First of all, I think it's…
# 962          RT @jessehawken: 2016: Come on, you're talking like Trump's going to put people in concentration camps2018: First of all, I think it's…
# 452          RT @jessehawken: 2016: Come on, you're talking like Trump's going to put people in concentration camps2018: First of all, I think it's…
# 494          RT @jessehawken: 2016: Come on, you're talking like Trump's going to put people in concentration camps2018: First of all, I think it's…
# 804          RT @jessehawken: 2016: Come on, you're talking like Trump's going to put people in concentration camps2018: First of all, I think it's…
# 790          RT @jessehawken: 2016: Come on, you're talking like Trump's going to put people in concentration camps2018: First of all, I think it's…
# 65            RT @ParkerMolloy: Since Melania Trump's jacket said I really don't care...I set up https://t.co/GL1FF0KpBsClick the link and it'll ta…
# 89            RT @ParkerMolloy: Since Melania Trump's jacket said I really don't care...I set up https://t.co/GL1FF0KpBsClick the link and it'll ta…
# 55            RT @ParkerMolloy: Since Melania Trump's jacket said I really don't care...I set up https://t.co/GL1FF0KpBsClick the link and it'll ta…
# 0                        TIME’s new cover: A reckoning after Trump's border separation policy: What kind of country are we?… https://t.co/iRrT5dtbp8
# 532         RT @ShaunKing: This is where we are right now. Corey Lewandowski, Trump's campaign manager. literally says Womp Womp when it is mention…
# 667         RT @ShaunKing: This is where we are right now. Corey Lewandowski, Trump's campaign manager. literally says Womp Womp when it is mention…
# 27          RT @ShaunKing: This is where we are right now. Corey Lewandowski, Trump's campaign manager. literally says Womp Womp when it is mention…
# 2         First, Trump created a crisis by repealing DACA, and threatened to deport DREAMErs if he didn’t get his wall.Next… https://t.co/45qfxDDvWe
# 586   RT @YG: We told y’all squares FUCK TRUMP 2 years ago,Y’all wanna start talking now tho. Y’all ain’t shit!BLACK &amp; BROWN PRIDE, Help them k…
# 1028  RT @YG: We told y’all squares FUCK TRUMP 2 years ago,Y’all wanna start talking now tho. Y’all ain’t shit!BLACK &amp; BROWN PRIDE, Help them k…
# 210   RT @YG: We told y’all squares FUCK TRUMP 2 years ago,Y’all wanna start talking now tho. Y’all ain’t shit!BLACK &amp; BROWN PRIDE, Help them k…
# 207   RT @YG: We told y’all squares FUCK TRUMP 2 years ago,Y’all wanna start talking now tho. Y’all ain’t shit!BLACK &amp; BROWN PRIDE, Help them k…
# 169   RT @YG: We told y’all squares FUCK TRUMP 2 years ago,Y’all wanna start talking now tho. Y’all ain’t shit!BLACK &amp; BROWN PRIDE, Help them k…
# 1054  RT @YG: We told y’all squares FUCK TRUMP 2 years ago,Y’all wanna start talking now tho. Y’all ain’t shit!BLACK &amp; BROWN PRIDE, Help them k…
# 909   RT @YG: We told y’all squares FUCK TRUMP 2 years ago,Y’all wanna start talking now tho. Y’all ain’t shit!BLACK &amp; BROWN PRIDE, Help them k…
# 608   RT @YG: We told y’all squares FUCK TRUMP 2 years ago,Y’all wanna start talking now tho. Y’all ain’t shit!BLACK &amp; BROWN PRIDE, Help them k…
# 328     RT @MrFilmkritik: Trump just signed an Executive Order he didn't need to sign to end a policy that he created and the White House said didn…
#
#       retweet_count
# 76            69093
# 153           69093
# 275           69093
# 413           69093
# 570           69093
# 587           69093
# 842           69093
# 738           63888
# 962           63888
# 452           63888
# 494           63888
# 804           63888
# 790           63888
# 65            52463
# 89            52463
# 55            52463
# 0             47157
# 532           44923
# 667           44923
# 27            44923
# 2             32136
# 586           29757
# 1028          29757
# 210           29757
# 207           29757
# 169           29757
# 1054          29757
# 909           29757
# 608           29757
# 328           24852

# %%
###################################################################################
# Remove duplicate texts.
###################################################################################

df_sub = df_sub.drop_duplicates(keep="first")
df_sub.sort_values(by="retweet_count", ascending=False).head(30)
# Out:
#                                                                                                                                                      text  \
# 76           RT @SteveSchmidtSES: 29 years and nine months ago I registered to vote and became a member of The Republican Party which was founded in 185…
# 452               RT @jessehawken: 2016: Come on, you're talking like Trump's going to put people in concentration camps2018: First of all, I think it's…
# 55                 RT @ParkerMolloy: Since Melania Trump's jacket said I really don't care...I set up https://t.co/GL1FF0KpBsClick the link and it'll ta…
# 0                             TIME’s new cover: A reckoning after Trump's border separation policy: What kind of country are we?… https://t.co/iRrT5dtbp8
# 27               RT @ShaunKing: This is where we are right now. Corey Lewandowski, Trump's campaign manager. literally says Womp Womp when it is mention…
# 2              First, Trump created a crisis by repealing DACA, and threatened to deport DREAMErs if he didn’t get his wall.Next… https://t.co/45qfxDDvWe
# 169        RT @YG: We told y’all squares FUCK TRUMP 2 years ago,Y’all wanna start talking now tho. Y’all ain’t shit!BLACK &amp; BROWN PRIDE, Help them k…
# 132          RT @MrFilmkritik: Trump just signed an Executive Order he didn't need to sign to end a policy that he created and the White House said didn…
# 199  RT @RepMaxineWaters: Remember when I said Trump &amp; his allies are scumbags? Trump is an immoral, indecent, &amp; inhumane thug.  He loves Putin,…
# 261          RT @realDonaldTrump: “FBI texts have revealed anti-Trump Bias.” @FoxNews  Big News, but the Fake News doesn’t want to cover. Total corrupti…
# 533            RT @chrislhayes: Here's what is happening: the Trump administration took 2500 kids as hostages and now congress is negotiating the ransom.
# 131          RT @DrDreddyMurphy: GOT A MAYOR NAME KEISHA SHE A REAL TOWN PLEASER. FELONS FROM CUBA STILL WORKIN ON DEY VISA. TRUMP STILL BITCHIN STILL T…
# 782               RT @Education4Libs: Racism didn’t work.Sexism didn’t work.Rigging the election didn’t work.Russia didn’t work.Gun control didn’t work.…
# 1            Here’s another zero tolerance program for the Trump Administration: EVERY child, EVERY baby has to be reunited with… https://t.co/e19PXYe4MH
# 5             RT @EricHolder: Here’s another zero tolerance program for the Trump Administration: EVERY child, EVERY baby has to be reunited with his or…
# 453          RT @ShaunKing: This is Rachel Maddow upon getting the breaking news that Trump has established detention centers for babies who've been for…
# 550          RT @MarkDice: So actor Peter Fonda (@IAmFonda) calls for Trump’s 12 year old son to be raped by pedophiles and @SonyPictures is still relea…
# 172          RT @krassenstein: BREAKING:  The US Senate Just rejected Trump's bid to defund the Child's health insurance program (CHIP) by billions of d…
# 190          RT @chrislhayes: If only there was some alternative to family detention. Wait: There is one! A successful case management pilot program tha…
# 119          RT @RealJamesWoods: It’s time for a vigorous pro-active @SecretService response to kidnap and rape threats against the twelve-year-old chil…
# 423          RT @MichaelSkolnik: Donald Trump has built prisons for babies. Donald Trump has built prisons for babies. Donald Trump has built prisons fo…
# 354          RT @ACLU: The Trump administration’s withdrawal from the UN Human Rights Council, coupled with its abusive use of power at home, only confi…
# 266          RT @johnpavlovitz: If you purposefully and unapologetically run people over with your car—you don't get points for stopping when lots of pe…
# 757          RT @JohnBrennan: It is the height of irony that the U.S. is withdrawing from UN Human Rights Council when the Trump Administration is perpe…
# 79           RT @Iapfeiffer: I'm screaming Cher really ate a cow's tongue rather than to say one (1) nice thing about Donald Trump lmaoo the legend, the…
# 126                                                                                                  RT @dumbfoundead: Fuck Trump https://t.co/soBO16mQiP
# 161          RT @KamalaHarris: Trump's executive order does not fix this crisis. It gives no solution for the thousands of children who have been torn a…
# 644          RT @JimCarrey: 40% of the US doesn’t care if Trump deports ppl, kidnaps their babies and uses them as political hostages. The time for diag…
# 425          RT @netanyahu: Israel thanks President Trump, Secretary Pompeo and Ambassador Haley for their courageous decision against the hypocrisy and…
# 398                 RT @RVAwonk: Speaking to the crowd in Duluth, Trump brings up Crooked Hillary and asks, How guilty is she?Crowd chants, Lock her up!…
#
#      retweet_count
# 76           69093
# 452          63888
# 55           52463
# 0            47157
# 27           44923
# 2            32136
# 169          29757
# 132          24852
# 199          22611
# 261          21705
# 533          20938
# 131          19206
# 782          17935
# 1            17914
# 5            17914
# 453          17092
# 550          16554
# 172          15618
# 190          15251
# 119          15051
# 423          14480
# 354          14455
# 266          13844
# 757          13361
# 79           13080
# 126          12500
# 161          12002
# 644          11321
# 425          10712
# 398          10586

# %% [markdown]
# ## Retweets vs. normal tweets

# %%
df[["text", "is_retweet"]].head(10)
# Out:
#                                                                                                                                                text  \
# 0                       TIME’s new cover: A reckoning after Trump's border separation policy: What kind of country are we?… https://t.co/iRrT5dtbp8
# 1      Here’s another zero tolerance program for the Trump Administration: EVERY child, EVERY baby has to be reunited with… https://t.co/e19PXYe4MH
# 2        First, Trump created a crisis by repealing DACA, and threatened to deport DREAMErs if he didn’t get his wall.Next… https://t.co/45qfxDDvWe
# 3      @parscale @KimKardashian Perhaps Kardashian would like to see USA transformed into a brutal dictatorship where peop… https://t.co/a0KNlaj2mq
# 4      RT @EdKrassen: President Trump, who says he won't show up in court for a Robert Mueller subpoena, claims that we must detain immigrants ind…
# 5       RT @EricHolder: Here’s another zero tolerance program for the Trump Administration: EVERY child, EVERY baby has to be reunited with his or…
# 6          RT @Education4Libs: First Lady Melania Trump took the time to visit a child detention center today in Texas.Strange.I don’t recall Mich…
# 7     RT @1Romans58: This POS is getting on my last nerve.  That fake smug smile needs to be removed. After Helping Plot &amp; Fund Trump Dossier,…
# 8  RT @TomArnold: If you are triggered by the abuse of children the full facts of how The Trump Administration has been housing &amp; abusing chil…
# 9      North Korea 'total denuclearisation' started; officials see no new moves - Trump - Reuters: Reuters North Korea 'to… https://t.co/F8zxPSgZzX
#
#    is_retweet
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# 5           1
# 6           1
# 7           1
# 8           1
# 9           0

# %%
count = df.groupby("is_retweet").id.count()

# %%
count
# Out:
# is_retweet
# 0    203
# 1    897
# Name: id, dtype: int64

# %%
count.plot.pie(labels=["Normal Tweets", "Retweets"], figsize=(5,5), autopct='%.1f')

# %% [markdown]
# ## Gender distribution

# %%
df[["user_name", "user_gender"]].head(10)
# Out:
#                    user_name user_gender
# 0                       TIME     unknown
# 1                Eric Holder        male
# 2                Adam Schiff        male
# 3                      Jarin     unknown
# 4               SharonBohn 🌊     unknown
# 5             Idella Sherrod      female
# 6               Bill Feltham        male
# 7           Deplorable Lessa     unknown
# 8  kaz #KeepFamiliesTogether     unknown
# 9               Yasmin Mitri      female

# %%
count = df.groupby("user_gender").user_id.count()

# %%
count
# Out:
# user_gender
# andy        14
# female     309
# male       258
# unknown    519
# Name: user_id, dtype: int64

# %%
count.plot.pie(figsize=(5,5), autopct='%.1f')

# %% [markdown]
# ## Sentiment distribution

# %%
from IPython.display import Image
Image(url="http://www.datavizcatalogue.com/methods/images/anatomy/box_plot.png")
# Out:
# <img src="http://www.datavizcatalogue.com/methods/images/anatomy/box_plot.png"/>

# %%
df[["polarity", "subjectivity"]].plot.box()

# %% [markdown]
# ## Retrieve tweets from a user's timeline

# %%
###################################################################################
# Retrieve recent tweets from President Trump's timeline on Twitter.  
###################################################################################

kwargs = {"screen_name": "realDonaldTrump", "count": 200, "include_rts": "true", "since_id": 1}
statuses = twitter_api.statuses.user_timeline(**kwargs)

# %% [markdown]
# Refer to President Donald Trump's official Twitter account: https://twitter.com/realDonaldTrump.

# %% [markdown]
# Refer to https://developer.twitter.com/en/docs/tweets/timelines/api-reference/get-statuses-user_timeline for more details.

# %%
###################################################################################
# Check the number of records in 'statuses'.
###################################################################################

len(statuses)
# Out:
# 200

# %%
###################################################################################
# Check the first record in 'statuses'.
###################################################################################

statuses[0]
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Fri Jun 22 02:12:34 +0000 2018',
#  'entities': {'hashtags': [],
#   'media': [{'display_url': 'pic.twitter.com/xsbuPzXbHj',
#     'expanded_url': 'https://twitter.com/realDonaldTrump/status/1009536237881847808/video/1',
#     'id': 1009535898302570496,
#     'id_str': '1009535898302570496',
#     'indices': [84, 107],
#     'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1009535898302570496/pu/img/vGlSJNJ2h4xc4gRp.jpg',
#     'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1009535898302570496/pu/img/vGlSJNJ2h4xc4gRp.jpg',
#     'sizes': {'large': {'h': 720, 'resize': 'fit', 'w': 1280},
#      'medium': {'h': 675, 'resize': 'fit', 'w': 1200},
#      'small': {'h': 383, 'resize': 'fit', 'w': 680},
#      'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#     'source_status_id': 1009536237881847808,
#     'source_status_id_str': '1009536237881847808',
#     'source_user_id': 25073877,
#     'source_user_id_str': '25073877',
#     'type': 'photo',
#     'url': 'https://t.co/xsbuPzXbHj'}],
#   'symbols': [],
#   'urls': [],
#   'user_mentions': [{'id': 25073877,
#     'id_str': '25073877',
#     'indices': [3, 19],
#     'name': 'Donald J. Trump',
#     'screen_name': 'realDonaldTrump'}]},
#  'extended_entities': {'media': [{'additional_media_info': {'monetizable': False,
#      'source_user': {'contributors_enabled': False,
#       'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#       'default_profile': False,
#       'default_profile_image': False,
#       'description': '45th President of the United States of America🇺🇸',
#       'entities': {'description': {'urls': []},
#        'url': {'urls': [{'display_url': 'Instagram.com/realDonaldTrump',
#           'expanded_url': 'http://www.Instagram.com/realDonaldTrump',
#           'indices': [0, 23],
#           'url': 'https://t.co/OMxB0xp8tD'}]}},
#       'favourites_count': 25,
#       'follow_request_sent': False,
#       'followers_count': 52984323,
#       'following': True,
#       'friends_count': 46,
#       'geo_enabled': True,
#       'has_extended_profile': False,
#       'id': 25073877,
#       'id_str': '25073877',
#       'is_translation_enabled': True,
#       'is_translator': False,
#       'lang': 'en',
#       'listed_count': 89426,
#       'location': 'Washington, DC',
#       'name': 'Donald J. Trump',
#       'notifications': False,
#       'profile_background_color': '6D5C18',
#       'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#       'profile_background_tile': True,
#       'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1529423542',
#       'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#       'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#       'profile_link_color': '1B95E0',
#       'profile_sidebar_border_color': 'BDDCAD',
#       'profile_sidebar_fill_color': 'C5CEC0',
#       'profile_text_color': '333333',
#       'profile_use_background_image': True,
#       'protected': False,
#       'screen_name': 'realDonaldTrump',
#       'statuses_count': 37947,
#       'time_zone': None,
#       'translator_type': 'regular',
#       'url': 'https://t.co/OMxB0xp8tD',
#       'utc_offset': None,
#       'verified': True}},
#     'display_url': 'pic.twitter.com/xsbuPzXbHj',
#     'expanded_url': 'https://twitter.com/realDonaldTrump/status/1009536237881847808/video/1',
#     'id': 1009535898302570496,
#     'id_str': '1009535898302570496',
#     'indices': [84, 107],
#     'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1009535898302570496/pu/img/vGlSJNJ2h4xc4gRp.jpg',
#     'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1009535898302570496/pu/img/vGlSJNJ2h4xc4gRp.jpg',
#     'sizes': {'large': {'h': 720, 'resize': 'fit', 'w': 1280},
#      'medium': {'h': 675, 'resize': 'fit', 'w': 1200},
#      'small': {'h': 383, 'resize': 'fit', 'w': 680},
#      'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#     'source_status_id': 1009536237881847808,
#     'source_status_id_str': '1009536237881847808',
#     'source_user_id': 25073877,
#     'source_user_id_str': '25073877',
#     'type': 'video',
#     'url': 'https://t.co/xsbuPzXbHj',
#     'video_info': {'aspect_ratio': [16, 9],
#      'duration_millis': 24640,
#      'variants': [{'bitrate': 2176000,
#        'content_type': 'video/mp4',
#        'url': 'https://video.twimg.com/ext_tw_video/1009535898302570496/pu/vid/1280x720/q0hmVlybR-lu973p.mp4?tag=3'},
#       {'bitrate': 832000,
#        'content_type': 'video/mp4',
#        'url': 'https://video.twimg.com/ext_tw_video/1009535898302570496/pu/vid/640x360/JR1HABLcRSwV32TY.mp4?tag=3'},
#       {'bitrate': 256000,
#        'content_type': 'video/mp4',
#        'url': 'https://video.twimg.com/ext_tw_video/1009535898302570496/pu/vid/320x180/ys1gr67Mtbrkg4AG.mp4?tag=3'},
#       {'content_type': 'application/x-mpegURL',
#        'url': 'https://video.twimg.com/ext_tw_video/1009535898302570496/pu/pl/Y2gobbxKhEIHqogz.m3u8?tag=3'}]}}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'geo': None,
#  'id': 1009982447822532608,
#  'id_str': '1009982447822532608',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'possibly_sensitive': False,
#  'retweet_count': 66866,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Wed Jun 20 20:39:30 +0000 2018',
#   'entities': {'hashtags': [],
#    'media': [{'display_url': 'pic.twitter.com/xsbuPzXbHj',
#      'expanded_url': 'https://twitter.com/realDonaldTrump/status/1009536237881847808/video/1',
#      'id': 1009535898302570496,
#      'id_str': '1009535898302570496',
#      'indices': [63, 86],
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1009535898302570496/pu/img/vGlSJNJ2h4xc4gRp.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1009535898302570496/pu/img/vGlSJNJ2h4xc4gRp.jpg',
#      'sizes': {'large': {'h': 720, 'resize': 'fit', 'w': 1280},
#       'medium': {'h': 675, 'resize': 'fit', 'w': 1200},
#       'small': {'h': 383, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'photo',
#      'url': 'https://t.co/xsbuPzXbHj'}],
#    'symbols': [],
#    'urls': [],
#    'user_mentions': []},
#   'extended_entities': {'media': [{'additional_media_info': {'monetizable': False},
#      'display_url': 'pic.twitter.com/xsbuPzXbHj',
#      'expanded_url': 'https://twitter.com/realDonaldTrump/status/1009536237881847808/video/1',
#      'id': 1009535898302570496,
#      'id_str': '1009535898302570496',
#      'indices': [63, 86],
#      'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1009535898302570496/pu/img/vGlSJNJ2h4xc4gRp.jpg',
#      'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1009535898302570496/pu/img/vGlSJNJ2h4xc4gRp.jpg',
#      'sizes': {'large': {'h': 720, 'resize': 'fit', 'w': 1280},
#       'medium': {'h': 675, 'resize': 'fit', 'w': 1200},
#       'small': {'h': 383, 'resize': 'fit', 'w': 680},
#       'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#      'type': 'video',
#      'url': 'https://t.co/xsbuPzXbHj',
#      'video_info': {'aspect_ratio': [16, 9],
#       'duration_millis': 24640,
#       'variants': [{'bitrate': 2176000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1009535898302570496/pu/vid/1280x720/q0hmVlybR-lu973p.mp4?tag=3'},
#        {'bitrate': 832000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1009535898302570496/pu/vid/640x360/JR1HABLcRSwV32TY.mp4?tag=3'},
#        {'bitrate': 256000,
#         'content_type': 'video/mp4',
#         'url': 'https://video.twimg.com/ext_tw_video/1009535898302570496/pu/vid/320x180/ys1gr67Mtbrkg4AG.mp4?tag=3'},
#        {'content_type': 'application/x-mpegURL',
#         'url': 'https://video.twimg.com/ext_tw_video/1009535898302570496/pu/pl/Y2gobbxKhEIHqogz.m3u8?tag=3'}]}}]},
#   'favorite_count': 173061,
#   'favorited': False,
#   'geo': None,
#   'id': 1009536237881847808,
#   'id_str': '1009536237881847808',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'possibly_sensitive': False,
#   'retweet_count': 66866,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'Don’t worry, the Republicans, and your President, will fix it! https://t.co/xsbuPzXbHj',
#   'truncated': False,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '45th President of the United States of America🇺🇸',
#    'entities': {'description': {'urls': []},
#     'url': {'urls': [{'display_url': 'Instagram.com/realDonaldTrump',
#        'expanded_url': 'http://www.Instagram.com/realDonaldTrump',
#        'indices': [0, 23],
#        'url': 'https://t.co/OMxB0xp8tD'}]}},
#    'favourites_count': 25,
#    'follow_request_sent': False,
#    'followers_count': 52984323,
#    'following': True,
#    'friends_count': 46,
#    'geo_enabled': True,
#    'has_extended_profile': False,
#    'id': 25073877,
#    'id_str': '25073877',
#    'is_translation_enabled': True,
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 89426,
#    'location': 'Washington, DC',
#    'name': 'Donald J. Trump',
#    'notifications': False,
#    'profile_background_color': '6D5C18',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1529423542',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'C5CEC0',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'realDonaldTrump',
#    'statuses_count': 37947,
#    'time_zone': None,
#    'translator_type': 'regular',
#    'url': 'https://t.co/OMxB0xp8tD',
#    'utc_offset': None,
#    'verified': True}},
#  'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#  'text': 'RT @realDonaldTrump: Don’t worry, the Republicans, and your President, will fix it! https://t.co/xsbuPzXbHj',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Wed Mar 18 13:46:38 +0000 2009',
#   'default_profile': False,
#   'default_profile_image': False,
#   'description': '45th President of the United States of America🇺🇸',
#   'entities': {'description': {'urls': []},
#    'url': {'urls': [{'display_url': 'Instagram.com/realDonaldTrump',
#       'expanded_url': 'http://www.Instagram.com/realDonaldTrump',
#       'indices': [0, 23],
#       'url': 'https://t.co/OMxB0xp8tD'}]}},
#   'favourites_count': 25,
#   'follow_request_sent': False,
#   'followers_count': 52984323,
#   'following': True,
#   'friends_count': 46,
#   'geo_enabled': True,
#   'has_extended_profile': False,
#   'id': 25073877,
#   'id_str': '25073877',
#   'is_translation_enabled': True,
#   'is_translator': False,
#   'lang': 'en',
#   'listed_count': 89426,
#   'location': 'Washington, DC',
#   'name': 'Donald J. Trump',
#   'notifications': False,
#   'profile_background_color': '6D5C18',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': True,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073877/1529423542',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/874276197357596672/kUuht00m_normal.jpg',
#   'profile_link_color': '1B95E0',
#   'profile_sidebar_border_color': 'BDDCAD',
#   'profile_sidebar_fill_color': 'C5CEC0',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'protected': False,
#   'screen_name': 'realDonaldTrump',
#   'statuses_count': 37947,
#   'time_zone': None,
#   'translator_type': 'regular',
#   'url': 'https://t.co/OMxB0xp8tD',
#   'utc_offset': None,
#   'verified': True}}

# %% [markdown]
# ## Retrieve more tweets from the user's timeline

# %%
#########################################################################
# 'Results' will be used for accumulating all incoming data from Twitter.
# Start by storing the previous data in 'results'.
#########################################################################

results = []
results += statuses

#########################################################################
# Make more iterative user timeline calls
#########################################################################

N = 15          # Maximum number of calls to be made.

i = 1
while (i <= N) and (len(statuses) > 0):
    
    ##########################################
    # Add a new key 'max_id' to kwargs 
    ##########################################
    
    kwargs["max_id"] = min([status["id"] for status in statuses]) - 1
    statuses = twitter_api.statuses.user_timeline(**kwargs)
    
    print("%d tweets retrieved." %len(statuses))
    
    ##########################################################
    # Add the current results to the overall results.
    ##########################################################
    
    results += statuses
    
    i += 1
# Out:
# 200 tweets retrieved.
# 200 tweets retrieved.
# 200 tweets retrieved.
# 200 tweets retrieved.
# 200 tweets retrieved.
# 200 tweets retrieved.
# 197 tweets retrieved.
# 200 tweets retrieved.
# 200 tweets retrieved.
# 199 tweets retrieved.
# 200 tweets retrieved.
# 200 tweets retrieved.
# 200 tweets retrieved.
# 200 tweets retrieved.
# 199 tweets retrieved.

# %% [markdown]
# This can only return up to 3,200 of a user’s most recent Tweets.

# %%
#########################################################################
# Check the number of records in 'results'.
#########################################################################

len(results)
# Out:
# 3195

# %% [markdown]
# ## Save the data as a CSV file

# %%
with open(file="user_timeline_data.csv", mode="w", encoding="utf8") as fw:
    fw.write("id\t" +
             "created_at\t" +
             "text\t" +
             "is_retweet\t" +
             "retweet_created_at\t" +
             "retweet_count\t" +
             "user_id\n")

    for status in results:
        fw.write(status["id_str"] + "\t")
        fw.write(status["created_at"] + "\t")
        fw.write(cleanse_text(status["text"]) + "\t")
        
        if "retweeted_status" in status:
            fw.write("1\t")
            fw.write(status["retweeted_status"]["created_at"] + "\t")
        else:
            fw.write("0\t")
            fw.write("\t")
        
        fw.write(str(status["retweet_count"]) + "\t")
        fw.write(status["user"]["id_str"])
        fw.write("\n")

# %% [markdown]
# ## Load the CSV file as a Pandas dataframe

# %%
df = pd.read_csv("user_timeline_data.csv", sep="\t", header=0, parse_dates=[1], index_col=False)

# %%
df.shape
# Out:
# (3195, 7)

# %%
df.columns
# Out:
# Index(['id', 'created_at', 'text', 'is_retweet', 'retweet_created_at',
#        'retweet_count', 'user_id'],
#       dtype='object')

# %%
df.head()
# Out:
#                     id          created_at  \
# 0  1009982447822532608 2018-06-22 02:12:34
# 1  1009935968164630528 2018-06-21 23:07:53
# 2  1009928980475138048 2018-06-21 22:40:07
# 3  1009916650622251009 2018-06-21 21:51:07
# 4  1009900449456115719 2018-06-21 20:46:44
#
#                                                                                                                                            text  \
# 0                                   RT @realDonaldTrump: Don’t worry, the Republicans, and your President, will fix it! https://t.co/xsbuPzXbHj
# 1  You cannot pass legislation on immigration whether it be for safety and security or any other reason including “hea… https://t.co/CxdDZUWyDy
# 2  We have to maintain strong borders or we will no longer have a country that we can be proud of – and if we show any… https://t.co/sjgqAjFi7m
# 3  “I REALLY DON’T CARE, DO U?” written on the back of Melania’s jacket, refers to the Fake News Media. Melania has le… https://t.co/sxYB9GYcmS
# 4  Big Supreme Court win on internet sales tax - about time! Big victory for fairness and for our country. Great victo… https://t.co/wV2cxGtsWA
#
#    is_retweet              retweet_created_at  retweet_count   user_id
# 0           1  Wed Jun 20 20:39:30 +0000 2018          66866  25073877
# 1           0                             NaN          18256  25073877
# 2           0                             NaN          23257  25073877
# 3           0                             NaN          32584  25073877
# 4           0                             NaN          11423  25073877

# %%
df.tail()
# Out:
#                       id          created_at  \
# 3190  857555256003227648 2017-04-27 11:21:20
# 3191  857552956836786177 2017-04-27 11:12:12
# 3192  857370270776086528 2017-04-26 23:06:16
# 3193  857360510534209536 2017-04-26 22:27:29
# 3194  857335793261568000 2017-04-26 20:49:16
#
#                                                                                                                                                   text  \
# 3190      ...subject to the fact that if we do not reach a fair deal for all, we will then terminate NAFTA. Relationships are good-deal very possible!
# 3191      I received calls from the President of Mexico and the Prime Minister of Canada asking to renegotiate NAFTA rather than terminate. I agreed..
# 3192                      Democrats are trying to bail out insurance companies from disastrous #ObamaCare, and Puerto Rico with your tax dollars. Sad!
# 3193  A great great honor to welcome &amp; recognize the National Teacher of the Year, as well as the Teacher of the Year fro… https://t.co/pUGl7RDoVX
# 3194              Today, I signed an Executive Order on Enforcing Statutory Prohibitions on Federal Control of Education. EO:… https://t.co/YYafFQncbC
#
#       is_retweet retweet_created_at  retweet_count   user_id
# 3190           0                NaN           9576  25073877
# 3191           0                NaN          15154  25073877
# 3192           0                NaN          14654  25073877
# 3193           0                NaN           9140  25073877
# 3194           0                NaN           8584  25073877

# %%
df["tags"] = df.text.apply(lambda x: TextBlob(x).tags)

# %%
df[["text", "tags"]].head()
# Out:
#                                                                                                                                            text  \
# 0                                   RT @realDonaldTrump: Don’t worry, the Republicans, and your President, will fix it! https://t.co/xsbuPzXbHj
# 1  You cannot pass legislation on immigration whether it be for safety and security or any other reason including “hea… https://t.co/CxdDZUWyDy
# 2  We have to maintain strong borders or we will no longer have a country that we can be proud of – and if we show any… https://t.co/sjgqAjFi7m
# 3  “I REALLY DON’T CARE, DO U?” written on the back of Melania’s jacket, refers to the Fake News Media. Melania has le… https://t.co/sxYB9GYcmS
# 4  Big Supreme Court win on internet sales tax - about time! Big victory for fairness and for our country. Great victo… https://t.co/wV2cxGtsWA
#
#                                                                                                                                                                                                       tags
# 0  [(RT, NNP), (@, NNP), (realDonaldTrump, NN), (Don, NNP), (’, NNP), (t, NN), (worry, NN), (the, DT), (Republicans, NNPS), (and, CC), (your, PRP$), (President, NNP), (will, MD), (fix, VB), (it, PRP)...
# 1  [(You, PRP), (can, MD), (not, RB), (pass, VB), (legislation, NN), (on, IN), (immigration, NN), (whether, IN), (it, PRP), (be, VB), (for, IN), (safety, NN), (and, CC), (security, NN), (or, CC), (an...
# 2  [(We, PRP), (have, VBP), (to, TO), (maintain, VB), (strong, JJ), (borders, NNS), (or, CC), (we, PRP), (will, MD), (no, RB), (longer, RB), (have, VB), (a, DT), (country, NN), (that, IN), (we, PRP),...
# 3  [(“, NN), (I, PRP), (REALLY, NNP), (DON, NNP), (’, NNP), (T, NNP), (CARE, NNP), (DO, NNP), (U, NNP), (”, NNP), (written, VBN), (on, IN), (the, DT), (back, NN), (of, IN), (Melania, NNP), (’, NNP), ...
# 4  [(Big, JJ), (Supreme, NNP), (Court, NNP), (win, VBP), (on, IN), (internet, NN), (sales, NNS), (tax, NN), (about, IN), (time, NN), (Big, JJ), (victory, NN), (for, IN), (fairness, NN), (and, CC), (f...

# %% [markdown]
# ## Keyword networks

# %% [markdown]
# In our keyword network,
# - a node represents a word,
# - an edge between two nodes represents the co-occurrences of the two words in tweets,
# - a node weight represents the word count,
# - and an edge weight represents the co-occurrence count of the two words.

# %%
###################################################################################
# Create a graph G. 
###################################################################################

G = nx.Graph()

# %%
#############################################################################################
# Define the number of nodes to consider. 
#############################################################################################

num_nodes = 25

# %%
###################################################################################
# The 'counter' object will have all the word count information. 
# The 'co_counter' object will have all the co-occurrence count information.
###################################################################################

counter = Counter()
co_counter = dict()

for tags in df.tags:

    word_set = set()
    for item in tags:
        word = item[0].lower()
        
        if word in (global_stopwords + local_stopwords):
            continue
        else:
            word_set.add(word)

    counter.update(word_set)
    
    ###################################################################################
    # Calculate co-occurrence count of two words and save it in 'co_counter' 
    ###################################################################################

    words = list(word_set)
    for word1 in words:
        if word1 not in co_counter:
            co_counter[word1] = dict()
        
        for word2 in words:

            ######################################
            # Skip if the two words are the same.
            ######################################

            if word1 == word2:
                continue
            
            if word2 not in co_counter[word1]:
                co_counter[word1][word2] = 1
            else:
                co_counter[word1][word2] += 1

# %%
###################################################################################
# Check the top-k popular words in 'counter'. 
###################################################################################

counter.most_common(num_nodes)
# Out:
# [('great', 537),
#  ('people', 220),
#  ('news', 204),
#  ('today', 195),
#  ('thank', 191),
#  ('fake', 169),
#  ('big', 150),
#  ('america', 149),
#  ('democrats', 149),
#  ('country', 145),
#  ('tax', 139),
#  ('many', 136),
#  ('u.s.', 123),
#  ('new', 114),
#  ('time', 105),
#  ('good', 105),
#  ('honor', 103),
#  ('much', 100),
#  ('house', 99),
#  ('american', 99),
#  ('korea', 96),
#  ('working', 96),
#  ('day', 96),
#  ('realdonaldtrump', 95),
#  ('want', 95)]

# %%
########################################################################################
# Check if the co-occurrence of word1 and word2 is the same as that of word2 and word1.
########################################################################################

co_counter["great"]["america"], co_counter["america"]["great"]
# Out:
# (63, 63)

# %%
###################################################################################
# Create a list of nodes and a list of node weights.
# Multiply each node weight by 10 to adjust the node size for better visualization.
###################################################################################

node_list = [item[0] for item in counter.most_common(num_nodes)]
node_weights = [item[1] * 10 for item in counter.most_common(num_nodes)]

# %%
###################################################################################
# Add each node to 'G' with the feature 'weight' being the word count. 
###################################################################################

for word in node_list:
    G.add_node(word, weight=counter.get(word))

# %%
###################################################################################
# Check what's in 'G' as nodes. 
###################################################################################

G.nodes.data()
# Out:
# NodeDataView({'great': {'weight': 537}, 'people': {'weight': 220}, 'news': {'weight': 204}, 'today': {'weight': 195}, 'thank': {'weight': 191}, 'fake': {'weight': 169}, 'big': {'weight': 150}, 'america': {'weight': 149}, 'democrats': {'weight': 149}, 'country': {'weight': 145}, 'tax': {'weight': 139}, 'many': {'weight': 136}, 'u.s.': {'weight': 123}, 'new': {'weight': 114}, 'time': {'weight': 105}, 'good': {'weight': 105}, 'honor': {'weight': 103}, 'much': {'weight': 100}, 'house': {'weight': 99}, 'american': {'weight': 99}, 'korea': {'weight': 96}, 'working': {'weight': 96}, 'day': {'weight': 96}, 'realdonaldtrump': {'weight': 95}, 'want': {'weight': 95}})

# %%
###########################################################################################
# Add each edge between nodes with the feature 'weight' being the co-occurrence count.
###########################################################################################

for word1 in node_list:
    for word2 in node_list:
        if (word1 != word2) & (word2 in co_counter[word1]):
            G.add_edge(word1, word2, weight=co_counter[word1][word2])

# %%
###################################################################################
# Check what's in G as edges. 
###################################################################################

G.edges.data()
# Out:
# EdgeDataView([('great', 'people', {'weight': 49}), ('great', 'news', {'weight': 28}), ('great', 'today', {'weight': 51}), ('great', 'thank', {'weight': 43}), ('great', 'fake', {'weight': 13}), ('great', 'big', {'weight': 38}), ('great', 'america', {'weight': 63}), ('great', 'democrats', {'weight': 9}), ('great', 'country', {'weight': 34}), ('great', 'tax', {'weight': 29}), ('great', 'many', {'weight': 28}), ('great', 'u.s.', {'weight': 17}), ('great', 'new', {'weight': 18}), ('great', 'time', {'weight': 13}), ('great', 'good', {'weight': 17}), ('great', 'honor', {'weight': 65}), ('great', 'much', {'weight': 14}), ('great', 'house', {'weight': 24}), ('great', 'american', {'weight': 18}), ('great', 'korea', {'weight': 11}), ('great', 'working', {'weight': 14}), ('great', 'day', {'weight': 30}), ('great', 'realdonaldtrump', {'weight': 9}), ('great', 'want', {'weight': 12}), ('people', 'news', {'weight': 13}), ('people', 'today', {'weight': 7}), ('people', 'thank', {'weight': 14}), ('people', 'fake', {'weight': 10}), ('people', 'big', {'weight': 12}), ('people', 'america', {'weight': 6}), ('people', 'democrats', {'weight': 10}), ('people', 'country', {'weight': 16}), ('people', 'tax', {'weight': 10}), ('people', 'many', {'weight': 17}), ('people', 'u.s.', {'weight': 9}), ('people', 'new', {'weight': 11}), ('people', 'time', {'weight': 8}), ('people', 'good', {'weight': 11}), ('people', 'honor', {'weight': 2}), ('people', 'much', {'weight': 3}), ('people', 'house', {'weight': 3}), ('people', 'american', {'weight': 24}), ('people', 'korea', {'weight': 4}), ('people', 'working', {'weight': 7}), ('people', 'day', {'weight': 5}), ('people', 'realdonaldtrump', {'weight': 7}), ('people', 'want', {'weight': 14}), ('news', 'today', {'weight': 5}), ('news', 'thank', {'weight': 4}), ('news', 'fake', {'weight': 152}), ('news', 'big', {'weight': 12}), ('news', 'america', {'weight': 4}), ('news', 'democrats', {'weight': 2}), ('news', 'country', {'weight': 7}), ('news', 'tax', {'weight': 6}), ('news', 'many', {'weight': 12}), ('news', 'u.s.', {'weight': 4}), ('news', 'new', {'weight': 5}), ('news', 'time', {'weight': 8}), ('news', 'good', {'weight': 17}), ('news', 'honor', {'weight': 2}), ('news', 'much', {'weight': 15}), ('news', 'house', {'weight': 7}), ('news', 'american', {'weight': 3}), ('news', 'korea', {'weight': 5}), ('news', 'working', {'weight': 6}), ('news', 'day', {'weight': 3}), ('news', 'realdonaldtrump', {'weight': 1}), ('news', 'want', {'weight': 8}), ('today', 'thank', {'weight': 11}), ('today', 'fake', {'weight': 4}), ('today', 'big', {'weight': 12}), ('today', 'america', {'weight': 8}), ('today', 'democrats', {'weight': 1}), ('today', 'country', {'weight': 6}), ('today', 'tax', {'weight': 10}), ('today', 'many', {'weight': 5}), ('today', 'u.s.', {'weight': 6}), ('today', 'new', {'weight': 6}), ('today', 'time', {'weight': 7}), ('today', 'good', {'weight': 6}), ('today', 'honor', {'weight': 40}), ('today', 'much', {'weight': 9}), ('today', 'house', {'weight': 15}), ('today', 'american', {'weight': 8}), ('today', 'korea', {'weight': 3}), ('today', 'working', {'weight': 5}), ('today', 'day', {'weight': 12}), ('today', 'realdonaldtrump', {'weight': 4}), ('today', 'want', {'weight': 4}), ('thank', 'fake', {'weight': 3}), ('thank', 'big', {'weight': 2}), ('thank', 'america', {'weight': 9}), ('thank', 'country', {'weight': 6}), ('thank', 'many', {'weight': 5}), ('thank', 'u.s.', {'weight': 8}), ('thank', 'new', {'weight': 4}), ('thank', 'time', {'weight': 6}), ('thank', 'honor', {'weight': 12}), ('thank', 'much', {'weight': 10}), ('thank', 'house', {'weight': 2}), ('thank', 'american', {'weight': 6}), ('thank', 'korea', {'weight': 2}), ('thank', 'working', {'weight': 8}), ('thank', 'day', {'weight': 3}), ('thank', 'realdonaldtrump', {'weight': 6}), ('thank', 'want', {'weight': 7}), ('fake', 'big', {'weight': 8}), ('fake', 'america', {'weight': 2}), ('fake', 'democrats', {'weight': 1}), ('fake', 'country', {'weight': 7}), ('fake', 'ta ...

# %%
###################################################################################
# Get a list of edges and a list of edge weights to be displayed. 
###################################################################################

edge_list = nx.get_edge_attributes(G, "weight").keys()
edge_weights = nx.get_edge_attributes(G, "weight").values()

# %%
###################################################################################
# Divide each edge weight by 10 to adjust the edge thickness for better visualization. 
###################################################################################

edge_weights = [item / 10 for item in edge_weights]

# %%
###################################################################################
# Draw the graph G.
###################################################################################

plt.figure(figsize=(10, 10))
nx.draw_spring(G, nodelist=node_list, node_size=node_weights, edgelist=edge_list, width=edge_weights,
                 node_color="yellow", with_labels=True)
plt.draw()

# %% [markdown]
# Types of drawing
# - draw_circular: draw the graph with a circular layout.
# - draw_random  : draw the graph with a random layout.
# - draw_spectral: draw the graph with a spectral layout.
# - draw_spring  : draw the graph with a spring layout.
# - draw_shell   : draw the graph with a shell layout.

# %%
plt.figure(figsize=(10, 10))
nx.draw_circular(G, nodelist=node_list, node_size=node_weights, edgelist=edge_list, width=edge_weights,
                 node_color="yellow", with_labels=True)
plt.draw()

# %% [markdown]
# ## Interactive visualization of keyword networks

# %%
def draw_network(period, layout):
    ###################################################################################
    # Filtering by period.
    ###################################################################################
    
    if period == "2Q 2018":
        df_tmp = df[(df.created_at >= "2018-04-01") & (df.created_at < "2018-07-01")]
    elif period == "1Q 2018":
        df_tmp = df[(df.created_at >= "2018-01-01") & (df.created_at < "2018-04-01")]
    elif period == "4Q 2017":
        df_tmp = df[(df.created_at >= "2017-10-01") & (df.created_at < "2018-01-01")]
    elif period == "3Q 2017":
        df_tmp = df[(df.created_at >= "2017-07-01") & (df.created_at < "2017-10-01")]
    elif period == "2Q 2017":
        df_tmp = df[(df.created_at >= "2017-04-01") & (df.created_at < "2017-07-01")]
    elif period == "1Q 2017":
        df_tmp = df[(df.created_at >= "2017-01-01") & (df.created_at < "2017-04-01")]
    else:
        df_tmp = df.copy()
    
    ###################################################################################
    # The same code as above.
    ###################################################################################
    
    counter = Counter()
    co_counter = dict()

    for tags in df_tmp.tags:
        word_set = set()
        for item in tags:
            word = item[0].lower()

            if word in (global_stopwords + local_stopwords):
                continue
            else:
                word_set.add(word)
        counter.update(word_set)

        words = list(word_set)
        for i in range(len(words)):
            word1 = words[i]
            if word1 not in co_counter:
                co_counter[word1] = dict()
            for j in range(len(words)):
                if j == i:
                    continue
                word2 = words[j]
                if word2 not in co_counter[word1]:
                    co_counter[word1][word2] = 1
                else:
                    co_counter[word1][word2] += 1

    G = nx.Graph()

    node_list = [item[0] for item in counter.most_common(num_nodes)]
    node_weights = [item[1] * 10 for item in counter.most_common(num_nodes)]

    for word in node_list:
        G.add_node(word, count=counter.get(word))

    for word1 in node_list:
        for word2 in node_list:
            if (word1 != word2) & (word2 in co_counter[word1]):
                G.add_edge(word1, word2, weight=co_counter[word1][word2])

    edge_list = nx.get_edge_attributes(G, "weight").keys()
    edge_weights = nx.get_edge_attributes(G, "weight").values()
    edge_weights = [item/10 for item in edge_weights]

    plt.figure(figsize=(10, 10))
    kwargs = {"nodelist": node_list, "node_size": node_weights, "edgelist": edge_list, "width": edge_weights, 
              "node_color": "yellow", "with_labels": True}
    
    ###################################################################################
    # Select the layout to be used for network visualization.
    ###################################################################################
    
    if layout == "Circular":
        nx.draw_circular(G, **kwargs)
    elif layout == "Random":
        nx.draw_random(G, **kwargs)
    elif layout == "Spring":
        nx.draw_spring(G, **kwargs)
    
    plt.draw()

# %%
###################################################################################
# Define a dropdown widget.
###################################################################################
w_d = widgets.Dropdown(
    options = ["All", "2Q 2018", "1Q 2018", "4Q 2017", "3Q 2017", "2Q 2017", "1Q 2017"],
    description = "Period",
    value = "All"
)

###################################################################################
# Define a toggle buttons widget.
###################################################################################
w_t = widgets.ToggleButtons(
    options = ["Circular", "Random", "Spring"],
    description = "Layout",
    value = "Spring"
)

# %%
###################################################################################
# Interactive interface for network visualization.
###################################################################################

interactive(draw_network, period=w_d, layout=w_t)
# Out:
# interactive(children=(Dropdown(description='Period', options=('All', '2Q 2018', '1Q 2018', '4Q 2017', '3Q 2017', '2Q 2017', '1Q 2017'), value='All'), ToggleButtons(description='Layout', index=2, options=('Circular', 'Random', 'Spring'), value='Spring'), Output()), _dom_classes=('widget-interact',))

# %% [markdown]
# ## Exercise #1

# %% [markdown]
# Retrieve the tweets from the timeline of former President Barack Obama (@BarackObama). Compare the keyword networks of the two presidents.

# %% [markdown]
# ## Exercise #2

# %% [markdown]
# You can do the same thing with social network analysis as we did with keyword network analysis. In a social network,
# - a node represents a user,
# - an edge between two nodes can represent the follow relationship of two users,
# - a node weight can represent the user's number of followers,
# - and an edge weight can represent the number of mentions between the two users.
